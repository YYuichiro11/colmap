# %%
import os
from pprint import pprint

GT_DIR = "./oxford5k_gt"
IMAGE_DIR = "./oxford5k_images"
OUTPUT_QUERY_IMAGE_DIR = "./oxford5k_query_images"
if not os.path.exists(OUTPUT_QUERY_IMAGE_DIR):
    os.mkdir(OUTPUT_QUERY_IMAGE_DIR)
OUTPUT_QUERY_IMAGE_LIST_PATH = "./oxford5k_query_image_list.txt"

files = os.listdir(GT_DIR)
filename_set = set()
for filename in files:
    filename = filename.replace(".txt", "")\
                        .replace("_ok", "") \
                        .replace("_good", "") \
                        .replace("_junk", "") \
                        .replace("_query", "")
                     
    # print(filename)
    filename_set.add(filename)
    
query_names = list(filename_set)
query_names.sort()

print("{} queres exists".format(len(query_names)))
pprint(query_names)

# %% [markdown]
# # Generate query image path list from Oxford5k queries
#
# This script generate `image path list` file which is used in colmap's image retrieval system.
# You have to feed it to the image retrieval system to get `rank list` files for each query.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

with open(OUTPUT_QUERY_IMAGE_LIST_PATH, "w") as list_file:
    for query_name in query_names:
        with open(os.path.join(GT_DIR, query_name+"_query.txt")) as f:
            query_info = f.readline().strip().split(" ")
        # print(query_info)

        # TODO: how to crop with float values? do we need interpolation?
        x_st = int(float(query_info[1]))
        y_st = int(float(query_info[2]))
        x_en = int(float(query_info[3]))
        y_en = int(float(query_info[4]))

        image_name = query_info[0].replace("oxc1_", "")
        image_path = os.path.join(IMAGE_DIR, image_name+".jpg")
        # print("open image:", image_path)
        img_bgr = cv2.imread(image_path)
        crop_img_bgr = img_bgr[y_st:y_en, x_st:x_en]


        img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
        crop_img = cv2.cvtColor(crop_img_bgr, cv2.COLOR_BGR2RGB)

        query_filename = query_name+".png"
        query_image_path = os.path.abspath(os.path.join(OUTPUT_QUERY_IMAGE_DIR, query_filename))
        cv2.imwrite(query_image_path, img_bgr)
        # cv2.imwrite(query_image_path, crop_img)
        list_file.write(query_filename+"\n")

    #     plt.figure()
    #     plt.imshow(img)
    #     plt.show()

    #     plt.figure()
    #     plt.imshow(crop_img)
    #     plt.show()
print("done")

# %% [markdown]
# # Compute mAP with rank list files

# %%
QUERY_RESULT_PATH = "./query_result.txt"

OUTPUT_RANK_LIST_DIR = "./oxford5k_rank_list"
if not os.path.exists(OUTPUT_RANK_LIST_DIR):
    os.mkdir(OUTPUT_RANK_LIST_DIR)

fh = None
with open(QUERY_RESULT_PATH, "r") as f:
    for line_idx, line in enumerate(f.readlines()):
        # print(line)
        if "Querying for image " in line:
            query_name = line.split(" ")[3]            
            if not fh is None:
                fh.close()
            fh = open(os.path.join(OUTPUT_RANK_LIST_DIR, query_name+"_rank.txt"), "w")
        else:      
            result_image_filename = line.strip().split(", ")[1].split("=")[1]
            result_image_name = result_image_filename.replace(".jpg", "")
            fh.write(result_image_name+"\n")

# %%
import os
import subprocess
from subprocess import CalledProcessError
import shlex

EXE_DIR_PATH = "."
WORK_DIR = "../ir_demo/"

def run_cmd(cmd, cwd=None):
    """
     limitation: cannot see progress until the process is finished. Not suitable for long-running task. 
    """
    try:       
        output = subprocess.check_output(cmd, shell=True, stderr=subprocess.STDOUT, cwd=cwd)
        output = output.decode('utf-8')
    except CalledProcessError as e:
        print(e)
        print("output: {}".format(e.output.decode('utf-8')))
    return output
        

cmd = "ls {EXE_DIR_PATH}".format( \
        EXE_DIR_PATH=EXE_DIR_PATH)
output = run_cmd(cmd)
print(output)
# Out:
# Evaluate Oxford5k.ipynb
# makefile
# oxford5k_compute_ap.cpp
# oxford5k_gt
# oxford5k_images
# oxford5k_query_image_list.txt
# oxford5k_query_images
# oxford5k_rank_list
# query_result.txt
# query_result_vocab_256_geomverif_1000.txt
# query_result_vocab_256_norerank.txt
# query_result_vocab_64_geomverif_1000.txt
# query_result_vocab_64_norerank.txt
# README.md

# %%
OXFORD_GT_WORKDIR = "./oxford5k_gt/"
# Relative PATH according to above work dir
RANK_LIST_DIR = "./oxford5k_rank_list"
COMPUTE_AP_EXE_PATH = "./oxford5k_compute_ap"

files = os.listdir(RANK_LIST_DIR)
ap_sum = 0.0
for f in files:
    query_name = f.split(".")[0]
    
    cmd = "{COMPUTE_AP_EXE_PATH} {QUERY_NAME} {RANK_LIST_FILE_PATH}".format(\
        COMPUTE_AP_EXE_PATH=COMPUTE_AP_EXE_PATH, \
        QUERY_NAME = query_name, \
        RANK_LIST_FILE_PATH = os.path.abspath(os.path.join(RANK_LIST_DIR, f)))
    output = run_cmd(cmd, cwd=OXFORD_GT_WORKDIR)
    print("cmd: ", cmd)
    print("AP: ", output)
    ap = float(output)
    ap_sum += ap
    
ap_mean = ap_sum / len(files)
print("mAP:", ap_mean)
# Out:
# cmd:  ./oxford5k_compute_ap all_souls_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/all_souls_1.png_rank.txt
# AP:  0.309307
#
# cmd:  ./oxford5k_compute_ap all_souls_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/all_souls_2.png_rank.txt
# AP:  0.470689
#
# cmd:  ./oxford5k_compute_ap all_souls_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/all_souls_3.png_rank.txt
# AP:  0.460129
#
# cmd:  ./oxford5k_compute_ap all_souls_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/all_souls_4.png_rank.txt
# AP:  0.683194
#
# cmd:  ./oxford5k_compute_ap all_souls_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/all_souls_5.png_rank.txt
# AP:  0.563944
#
# cmd:  ./oxford5k_compute_ap ashmolean_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/ashmolean_1.png_rank.txt
# AP:  0.452594
#
# cmd:  ./oxford5k_compute_ap ashmolean_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/ashmolean_2.png_rank.txt
# AP:  0.537169
#
# cmd:  ./oxford5k_compute_ap ashmolean_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/ashmolean_3.png_rank.txt
# AP:  0.154361
#
# cmd:  ./oxford5k_compute_ap ashmolean_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/ashmolean_4.png_rank.txt
# AP:  0.145761
#
# cmd:  ./oxford5k_compute_ap ashmolean_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/ashmolean_5.png_rank.txt
# AP:  0.415279
#
# cmd:  ./oxford5k_compute_ap balliol_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/balliol_1.png_rank.txt
# AP:  0.45182
#
# cmd:  ./oxford5k_compute_ap balliol_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/balliol_2.png_rank.txt
# AP:  0.146685
#
# cmd:  ./oxford5k_compute_ap balliol_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/balliol_3.png_rank.txt
# AP:  0.461169
#
# cmd:  ./oxford5k_compute_ap balliol_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/balliol_4.png_rank.txt
# AP:  0.394041
#
# cmd:  ./oxford5k_compute_ap balliol_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/balliol_5.png_rank.txt
# AP:  0.57586
#
# cmd:  ./oxford5k_compute_ap bodleian_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/bodleian_1.png_rank.txt
# AP:  0.58528
#
# cmd:  ./oxford5k_compute_ap bodleian_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/bodleian_2.png_rank.txt
# AP:  0.608427
#
# cmd:  ./oxford5k_compute_ap bodleian_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/bodleian_3.png_rank.txt
# AP:  0.413018
#
# cmd:  ./oxford5k_compute_ap bodleian_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/bodleian_4.png_rank.txt
# AP:  0.794214
#
# cmd:  ./oxford5k_compute_ap bodleian_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/bodleian_5.png_rank.txt
# AP:  0.736293
#
# cmd:  ./oxford5k_compute_ap christ_church_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/christ_church_1.png_rank.txt
# AP:  0.677135
#
# cmd:  ./oxford5k_compute_ap christ_church_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/christ_church_2.png_rank.txt
# AP:  0.688037
#
# cmd:  ./oxford5k_compute_ap christ_church_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/christ_church_3.png_rank.txt
# AP:  0.66203
#
# cmd:  ./oxford5k_compute_ap christ_church_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/christ_church_4.png_rank.txt
# AP:  0.751426
#
# cmd:  ./oxford5k_compute_ap christ_church_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/christ_church_5.png_rank.txt
# AP:  0.144997
#
# cmd:  ./oxford5k_compute_ap cornmarket_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/cornmarket_1.png_rank.txt
# AP:  0.726892
#
# cmd:  ./oxford5k_compute_ap cornmarket_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/cornmarket_2.png_rank.txt
# AP:  0.119679
#
# cmd:  ./oxford5k_compute_ap cornmarket_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/cornmarket_3.png_rank.txt
# AP:  0.56998
#
# cmd:  ./oxford5k_compute_ap cornmarket_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/cornmarket_4.png_rank.txt
# AP:  0.559689
#
# cmd:  ./oxford5k_compute_ap cornmarket_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/cornmarket_5.png_rank.txt
# AP:  0.352902
#
# cmd:  ./oxford5k_compute_ap hertford_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/hertford_1.png_rank.txt
# AP:  0.725639
#
# cmd:  ./oxford5k_compute_ap hertford_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/hertford_2.png_rank.txt
# AP:  0.626576
#
# cmd:  ./oxford5k_compute_ap hertford_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/hertford_3.png_rank.txt
# AP:  0.480503
#
# cmd:  ./oxford5k_compute_ap hertford_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/hertford_4.png_rank.txt
# AP:  0.739116
#
# cmd:  ./oxford5k_compute_ap hertford_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/hertford_5.png_rank.txt
# AP:  0.345078
#
# cmd:  ./oxford5k_compute_ap keble_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/keble_1.png_rank.txt
# AP:  0.653912
#
# cmd:  ./oxford5k_compute_ap keble_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/keble_2.png_rank.txt
# AP:  0.884034
#
# cmd:  ./oxford5k_compute_ap keble_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/keble_3.png_rank.txt
# AP:  0.792075
#
# cmd:  ./oxford5k_compute_ap keble_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/keble_4.png_rank.txt
# AP:  0.606209
#
# cmd:  ./oxford5k_compute_ap keble_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/keble_5.png_rank.txt
# AP:  0.887175
#
# cmd:  ./oxford5k_compute_ap magdalen_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/magdalen_1.png_rank.txt
# AP:  0.0771955
#
# cmd:  ./oxford5k_compute_ap magdalen_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/magdalen_2.png_rank.txt
# AP:  0.250048
#
# cmd:  ./oxford5k_compute_ap magdalen_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/magdalen_3.png_rank.txt
# AP:  0.195895
#
# cmd:  ./oxford5k_compute_ap magdalen_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/magdalen_4.png_rank.txt
# AP:  0.0260586
#
# cmd:  ./oxford5k_compute_ap magdalen_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/magdalen_5.png_rank.txt
# AP:  0.116044
#
# cmd:  ./oxford5k_compute_ap pitt_rivers_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/pitt_rivers_1.png_rank.txt
# AP:  1
#
# cmd:  ./oxford5k_compute_ap pitt_rivers_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/pitt_rivers_2.png_rank.txt
# AP:  1
#
# cmd:  ./oxford5k_compute_ap pitt_rivers_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/pitt_rivers_3.png_rank.txt
# AP:  1
#
# cmd:  ./oxford5k_compute_ap pitt_rivers_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/pitt_rivers_4.png_rank.txt
# AP:  1
#
# cmd:  ./oxford5k_compute_ap pitt_rivers_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/pitt_rivers_5.png_rank.txt
# AP:  0.828274
#
# cmd:  ./oxford5k_compute_ap radcliffe_camera_1 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/radcliffe_camera_1.png_rank.txt
# AP:  0.719314
#
# cmd:  ./oxford5k_compute_ap radcliffe_camera_2 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/radcliffe_camera_2.png_rank.txt
# AP:  0.521399
#
# cmd:  ./oxford5k_compute_ap radcliffe_camera_3 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/radcliffe_camera_3.png_rank.txt
# AP:  0.741154
#
# cmd:  ./oxford5k_compute_ap radcliffe_camera_4 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/radcliffe_camera_4.png_rank.txt
# AP:  0.473107
#
# cmd:  ./oxford5k_compute_ap radcliffe_camera_5 /home1/irteam/users/insikk/colmap/eval/oxford5k_rank_list/radcliffe_camera_5.png_rank.txt
# AP:  0.630482
#
# mAP: 0.5442052563636361
